# %%
import pandas as pd
path='/content/ign.csv'
data=pd.read_csv(path)
print(type(data))
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (18625, 10)

# %%
data.head(6)
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
# 5         Good                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# ...

# %%
data.tail(6)
# Out:
#       score_phrase                                    title  \
# 18619         Good                          Human Fall Flat
# 18620         Good                Tokyo Mirage Sessions #FE
# 18621      Amazing        LEGO Star Wars: The Force Awakens
# 18622     Mediocre  Star Ocean: Integrity and Faithlessness
# 18623  Masterpiece                                   Inside
# 18624  Masterpiece                                   Inside
#
#                                                      url       platform  \
# 18619                 /games/human-fall-flat/pc-20051928             PC
# 18620  /games/fire-emblem-x-shin-megami-tensei/wii-u-...          Wii U
# 18621  /games/lego-star-wars-the-force-awakens/ps4-20...  PlayStation 4
# 18622                   /games/star-ocean-5/ps4-20035681  PlayStation 4
# 18623             /games/inside-playdead/xbox-one-121435       Xbox One
# 18624                 /games/inside-playdead/pc-20055740             PC
#
# ...

# %%
data.iloc[2:6,[3,0,4]]
# Out:
#         platform score_phrase  score
# 2           iPad        Great    8.5
# 3       Xbox 360        Great    8.5
# 4  PlayStation 3        Great    8.5
# 5      Macintosh         Good    7.0

# %%
data.loc[2:5,['genre','score_phrase']]
# Out:
#       genre score_phrase
# 2    Puzzle        Great
# 3    Sports        Great
# 4    Sports        Great
# 5  Strategy         Good

# %%
data['url']
# Out:
# 0                   /games/littlebigplanet-vita/vita-98907
# 1        /games/littlebigplanet-ps-vita-marvel-super-he...
# 2                                /games/splice/ipad-141070
# 3                            /games/nhl-13/xbox-360-128182
# 4                                 /games/nhl-13/ps3-128181
#                                ...
# 18620    /games/fire-emblem-x-shin-megami-tensei/wii-u-...
# 18621    /games/lego-star-wars-the-force-awakens/ps4-20...
# 18622                     /games/star-ocean-5/ps4-20035681
# 18623               /games/inside-playdead/xbox-one-121435
# 18624                   /games/inside-playdead/pc-20055740
# Name: url, Length: 18625, dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18625 entries, 0 to 18624
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   score_phrase    18625 non-null  object
#  1   title           18625 non-null  object
#  2   url             18625 non-null  object
#  3   platform        18625 non-null  object
#  4   score           18625 non-null  float64
#  5   genre           18589 non-null  object
#  6   editors_choice  18625 non-null  object
#  7   release_year    18625 non-null  int64
#  8   release_month   18625 non-null  int64
#  9   release_day     18625 non-null  int64
# dtypes: float64(1), int64(3), object(6)
# memory usage: 1.4+ MB

# %%
score=data['score']
avg=score.mean()
min=score.min()
max=score.max()
var=score.var()
std=score.std()

print("average:",avg)
print("Minimum:",min)
print("Maximum",max)
print("Standard deviation",std)
print("VAriance",var)
# Out:
# average: 6.950459060402685
# Minimum: 0.5
# Maximum 10.0
# Standard deviation 1.7117358608046402
# VAriance 2.9300396571646026

# %%
data.describe()
# Out:
#               score  release_year  release_month   release_day
# count  18625.000000  18625.000000    18625.00000  18625.000000
# mean       6.950459   2006.515329        7.13847     15.603866
# std        1.711736      4.587529        3.47671      8.690128
# min        0.500000   1970.000000        1.00000      1.000000
# 25%        6.000000   2003.000000        4.00000      8.000000
# 50%        7.300000   2007.000000        8.00000     16.000000
# 75%        8.200000   2010.000000       10.00000     23.000000
# max       10.000000   2016.000000       12.00000     31.000000

# %%
score.describe()
# Out:
# count    18625.000000
# mean         6.950459
# std          1.711736
# min          0.500000
# 25%          6.000000
# 50%          7.300000
# 75%          8.200000
# max         10.000000
# Name: score, dtype: float64

# %%
phrase=data['score_phrase'].unique()
print(phrase)
# Out:
# ['Amazing' 'Great' 'Good' 'Awful' 'Okay' 'Mediocre' 'Bad' 'Painful'
#  'Unbearable' 'Disaster' 'Masterpiece']

# %%
year=data['release_year'].unique()
print(year)
# Out:
# [2012 2013 1996 1970 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006
#  2007 2008 2009 2010 2011 2014 2015 2016]

# %%
games_number=data['release_year'].value_counts()
print(games_number)
# Out:
# release_year
# 2008    1915
# 2009    1687
# 2007    1610
# 2010    1363
# 2006    1208
# 2005    1088
# 2011    1073
# 2000    1045
# 2004     997
# 2003     969
# 2002     936
# 1999     775
# 2012     753
# 2013     696
# 2001     688
# 2014     537
# 2015     365
# 1998     339
# 2016     226
# 1997     205
# 1996     149
# 1970       1
# Name: count, dtype: int64

# %%
ind=data['platform']=='PC'
new_data=data[ind]
print("total numbber of PC games are:",new_data.shape[0])
# Out:
# total numbber of PC games are: 3370

# %%
ind1=data['score_phrase']=='Amazing'
newdata1=data[ind1]
print('number of Amazing games are:',newdata1.shape[0])
# Out:
# number of Amazing games are: 1804

# %%
ind=(data['platform']=='PC')&(data['score_phrase']=='Amazing')
ndata=data[ind]
print('total numnber of amazing PC games are:',ndata.shape[0])
# Out:
# total numnber of amazing PC games are: 351
